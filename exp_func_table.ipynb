# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from htrace import Parse
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %config InlineBackend.figure_formats = ['svg']
sns.set_style("whitegrid")

# %%
data_path={
    'dfsioe_r': 'data/dfsioe_r/',
    'dfsioe_w': 'data/dfsioe_w/',
    'kmeans': 'data/kmeans/',
    'pagerank': 'data/pagerank/',
    'terasort': 'data/terasort/',
    'wordcount': 'data/wordcount/'
}
samplers = ['a', 'l', 't', 'p0.1', 'p0.01']
zh_samplers = ['全采样','限制采样','令牌桶采样','概率采样(0.1)','概率采样(0.01)']

# %% [markdown]
# ## 不同函数的采样个数对比

# %%
def clean_src_csv(path):
    df = pd.read_csv(path+'/1.csv')
    df.index = df['Unnamed: 0']
    df.drop(['Unnamed: 0'],axis=1, inplace=True)
    df = df.T
    df.columns = ['count','mean','std','min','25%','50%','75%','max']
    return df['count'].to_frame()

# %%
def bench_func_display(bench):
    res = []
    for sampler in samplers:
        res.append(clean_src_csv(bench+sampler))
    c = pd.concat(res, axis=1, sort=True)
    c.columns = zh_samplers
    return c[(c['全采样']<10000)&(c['全采样']>10)]

# %%
for name, bench in data_path.items():
    print(bench)
    bench_func_display(bench)
# Out:
# data/dfsioe_r/
#                                              全采样    限制采样   令牌桶采样  概率采样(0.1)  \
# BlockReaderRemote2#readNextPacket         5184.0   131.0    73.0      501.0
# ClientNamenodeProtocol#addBlock             35.0    35.0    35.0        4.0
# ClientNamenodeProtocol#complete             37.0    37.0    37.0        3.0
# ClientNamenodeProtocol#create               37.0    37.0    37.0        2.0
# ClientNamenodeProtocol#getBlockLocations    70.0    70.0    70.0        6.0
# ClientNamenodeProtocol#getFileInfo          81.0    81.0    81.0        8.0
# DFSInputStream#fetchBlockAt                 68.0    11.0     5.0        5.0
# DFSInputStream#openInfo                     69.0    69.0    69.0        6.0
# DFSOutputStream#close                       37.0    37.0    37.0        3.0
# DFSOutputStream#flushInternal               37.0    37.0    37.0        3.0
# DFSOutputStream#write                      440.0   183.0   440.0       43.0
# DFSOutputStream#writeChunk                3694.0  1375.0  3690.0      363.0
# DataStreamer#writeTo                        98.0    98.0    98.0       19.0
# DistributedFileSystem#create                37.0    37.0    37.0        2.0
# DistributedFileSystem#open                  69.0    69.0    69.0        6.0
# completeFile                                37.0    37.0    37.0        3.0
# dataStreamer                                98.0    84.0    98.0       11.0
# getBlockLocations                           70.0    70.0    70.0        6.0
# getFileInfo                                 81.0    81.0    81.0        8.0
# newDFSInputStream                           69.0    69.0    69.0        6.0
# newStreamForCreate                          37.0    37.0    37.0        2.0
# waitForAckedSeqno                           37.0    37.0    37.0        3.0
#
#                                           概率采样(0.01)
# BlockReaderRemote2#readNextPacket               38.0
# ClientNamenodeProtocol#addBlock                  1.0
# ClientNamenodeProtocol#complete                  1.0
# ClientNamenodeProtocol#create                    NaN
# ClientNamenodeProtocol#getBlockLocations         1.0
# ClientNamenodeProtocol#getFileInfo               NaN
# DFSInputStream#fetchBlockAt                      NaN
# DFSInputStream#openInfo                          1.0
# DFSOutputStream#close                            1.0
# DFSOutputStream#flushInternal                    1.0
# DFSOutputStream#write                            4.0
# DFSOutputStream#writeChunk                      28.0
# DataStreamer#writeTo                             4.0
# DistributedFileSystem#create                     NaN
# DistributedFileSystem#open                       1.0
# completeFile                                     1.0
# dataStreamer                                     2.0
# getBlockLocations                                1.0
# getFileInfo                                      NaN
# newDFSInputStream                                1.0
# newStreamForCreate                               NaN
# waitForAckedSeqno                                1.0
# data/dfsioe_w/
#                                              全采样    限制采样   令牌桶采样  概率采样(0.1)  \
# BlockReaderRemote2#readNextPacket           64.0    45.0    64.0        6.0
# ClientNamenodeProtocol#addBlock             67.0    40.0    36.0        9.0
# ClientNamenodeProtocol#complete             69.0    69.0    69.0        9.0
# ClientNamenodeProtocol#create               69.0    69.0    69.0        6.0
# ClientNamenodeProtocol#getBlockLocations    38.0    38.0    38.0        3.0
# ClientNamenodeProtocol#getFileInfo          81.0    81.0    81.0        9.0
# DFSInputStream#byteArrayRead              1139.0   826.0  1136.0       96.0
# DFSInputStream#fetchBlockAt                 36.0    34.0    36.0        3.0
# DFSInputStream#openInfo                     37.0    37.0    37.0        3.0
# DFSInputStream#readWithStrategy           1139.0   826.0  1136.0       96.0
# DFSOutputStream#close                       69.0    69.0    69.0        9.0
# DFSOutputStream#flushInternal               69.0    69.0    69.0        9.0
# DataStreamer#writeTo                      5346.0  1625.0  1542.0     1052.0
# DistributedFileSystem#create                69.0    69.0    69.0        6.0
# DistributedFileSystem#open                  37.0    37.0    37.0        3.0
# completeFile                                69.0    69.0    69.0        9.0
# dataStreamer                              5346.0   278.0   213.0      525.0
# getBlockLocations                           38.0    38.0    38.0        3.0
# getFileInfo                                 81.0    81.0    81.0        9.0
# newDFSInputStream                           37.0    37.0    37.0        3.0
# newStreamForCreate                          69.0    69.0    69.0        6.0
# waitForAckedSeqno                           69.0    69.0    69.0        9.0
#
#                                           概率采样(0.01)
# BlockReaderRemote2#readNextPacket                1.0
# ClientNamenodeProtocol#addBlock                  2.0
# ClientNamenodeProtocol#complete                  2.0
# ClientNamenodeProtocol#create                    NaN
# ClientNamenodeProtocol#getBlockLocations         NaN
# ClientNamenodeProtocol#getFileInfo               1.0
# DFSInputStream#byteArrayRead                    17.0
# DFSInputStream#fetchBlockAt                      1.0
# DFSInputStream#openInfo                          NaN
# DFSInputStream#readWithStrategy                 17.0
# DFSOutputStream#close                            2.0
# DFSOutputStream#flushInternal                    2.0
# DataStreamer#writeTo                           105.0
# DistributedFileSystem#create                     NaN
# DistributedFileSystem#open                       NaN
# completeFile                                     2.0
# dataStreamer                                    54.0
# getBlockLocations                                NaN
# getFileInfo                                      1.0
# newDFSInputStream                                NaN
# newStreamForCreate                               NaN
# waitForAckedSeqno                                2.0
# data/kmeans/
#                                              全采样    限制采样   令牌桶采样  概率采样(0.1)  \
# BlockReaderRemote2#readNextPacket          251.0    42.0    22.0       21.0
# ClientNamenodeProtocol#addBlock             22.0    22.0    22.0        4.0
# ClientNamenodeProtocol#complete             28.0    28.0    28.0        3.0
# ClientNamenodeProtocol#create               28.0    28.0    28.0        4.0
# ClientNamenodeProtocol#getBlockLocations   131.0   131.0   131.0       16.0
# ClientNamenodeProtocol#getFileInfo         219.0   219.0   219.0       19.0
# ClientNamenodeProtocol#getListing           73.0    73.0    73.0       10.0
# ClientNamenodeProtocol#rename               21.0    21.0    21.0        3.0
# DFSClient#rename                            21.0    21.0    21.0        3.0
# DFSInputStream#fetchBlockAt                131.0    41.0    22.0       11.0
# DFSInputStream#openInfo                    131.0   131.0   131.0       16.0
# DFSOutputStream#close                       28.0    28.0    28.0        3.0
# DFSOutputStream#flushInternal               28.0    28.0    28.0        3.0
# DFSOutputStream#write                      567.0   567.0   567.0       62.0
# DFSOutputStream#writeChunk                4963.0  4963.0  4963.0      536.0
# DataStreamer#writeTo                        79.0    79.0    79.0       13.0
# DistributedFileSystem#create                28.0    28.0    28.0        4.0
# DistributedFileSystem#open                 131.0   131.0   131.0       16.0
# completeFile                                28.0    28.0    28.0        3.0
# dataStreamer                                79.0    79.0    79.0        7.0
# getBlockLocations                          131.0   131.0   131.0       16.0
# getFileInfo                                219.0   219.0   219.0       19.0
# listPaths                                   73.0    73.0    73.0       10.0
# newDFSInputStream                          131.0   131.0   131.0       16.0
# newStreamForCreate                          28.0    28.0    28.0        4.0
# waitForAckedSeqno                           28.0    28.0    28.0        3.0
#
#                                           概率采样(0.01)
# BlockReaderRemote2#readNextPacket                3.0
# ClientNamenodeProtocol#addBlock                  NaN
# ClientNamenodeProtocol#complete                  NaN
# ClientNamenodeProtocol#create                    NaN
# ClientNamenodeProtocol#getBlockLocations         1.0
# ClientNamenodeProtocol#getFileInfo               4.0
# ClientNamenodeProtocol#getListing                1.0
# ClientNamenodeProtocol#rename                    NaN
# DFSClient#rename                                 NaN
# DFSInputStream#fetchBlockAt                      1.0
# DFSInputStream#openInfo                          1.0
# DFSOutputStream#close                            NaN
# DFSOutputStream#flushInternal                    NaN
# DFSOutputStream#write                            9.0
# DFSOutputStream#writeChunk                      81.0
# DataStreamer#writeTo                             2.0
# DistributedFileSystem#create                     NaN
# DistributedFileSystem#open                       1.0
# completeFile                                     NaN
# dataStreamer                                     1.0
# getBlockLocations                                1.0
# getFileInfo                                      4.0
# listPaths                                        1.0
# newDFSInputStream                                1.0
# newStreamForCreate                               NaN
# waitForAckedSeqno                                NaN
# data/pagerank/
#                                              全采样    限制采样   令牌桶采样  概率采样(0.1)  \
# BlockReaderRemote2#readNextPacket         3749.0   133.0   114.0      364.0
# ClientNamenodeProtocol#addBlock            241.0   129.0   127.0       33.0
# ClientNamenodeProtocol#complete            247.0   247.0   247.0       32.0
# ClientNamenodeProtocol#create              247.0   247.0   247.0       31.0
# ClientNamenodeProtocol#delete               12.0    12.0    12.0        1.0
# ClientNamenodeProtocol#getBlockLocations   321.0   301.0   321.0       27.0
# ClientNamenodeProtocol#getFileInfo        1537.0  1024.0  1537.0      157.0
# ClientNamenodeProtocol#getListing          255.0    91.0   255.0       28.0
# ClientNamenodeProtocol#rename              483.0   483.0   483.0       52.0
# DFSClient#delete                            12.0    12.0    12.0        1.0
# DFSClient#rename                           483.0   483.0   483.0       52.0
# DFSInputStream#fetchBlockAt                321.0    49.0     9.0       31.0
# DFSInputStream#openInfo                    321.0   301.0   321.0       27.0
# DFSOutputStream#close                      247.0   247.0   247.0       32.0
# DFSOutputStream#flushInternal              247.0   247.0   247.0       32.0
# DataStreamer#writeTo                      3012.0  1224.0  2662.0      585.0
# DistributedFileSystem#create               247.0   247.0   247.0       31.0
# DistributedFileSystem#delete                12.0    12.0    12.0        1.0
# DistributedFileSystem#open                 321.0   301.0   321.0       27.0
# completeFile                               247.0   247.0   247.0       32.0
# dataStreamer                              3012.0   547.0   608.0      325.0
# delete                                      12.0    12.0    12.0        1.0
# getBlockLocations                          321.0   301.0   321.0       27.0
# getFileInfo                               1537.0  1024.0  1537.0      157.0
# listPaths                                  255.0    91.0   255.0       28.0
# newDFSInputStream                          321.0   301.0   321.0       27.0
# newStreamForCreate                         247.0   247.0   247.0       31.0
# waitForAckedSeqno                          247.0   247.0   247.0       32.0
#
#                                           概率采样(0.01)
# BlockReaderRemote2#readNextPacket               37.0
# ClientNamenodeProtocol#addBlock                  2.0
# ClientNamenodeProtocol#complete                  2.0
# ClientNamenodeProtocol#create                    4.0
# ClientNamenodeProtocol#delete                    NaN
# ClientNamenodeProtocol#getBlockLocations         3.0
# ClientNamenodeProtocol#getFileInfo               7.0
# ClientNamenodeProtocol#getListing                5.0
# ClientNamenodeProtocol#rename                    2.0
# DFSClient#delete                                 NaN
# DFSClient#rename                                 2.0
# DFSInputStream#fetchBlockAt                      5.0
# DFSInputStream#openInfo                          3.0
# DFSOutputStream#close                            2.0
# DFSOutputStream#flushInternal                    2.0
# DataStreamer#writeTo                            60.0
# DistributedFileSystem#create                     4.0
# DistributedFileSystem#delete                     NaN
# DistributedFileSystem#open                       3.0
# completeFile                                     2.0
# dataStreamer                                    27.0
# delete                                           NaN
# getBlockLocations                                3.0
# getFileInfo                                      7.0
# listPaths                                        5.0
# newDFSInputStream                                3.0
# newStreamForCreate                               4.0
# waitForAckedSeqno                                2.0
# data/terasort/
#                                        全采样   限制采样   令牌桶采样  概率采样(0.1)  \
# BlockReaderRemote2#readNextPacket    643.0   12.0     3.0       72.0
# ClientNamenodeProtocol#addBlock       41.0    7.0    11.0        3.0
# ClientNamenodeProtocol#complete       42.0   42.0    42.0        6.0
# ClientNamenodeProtocol#create         42.0   42.0    42.0        4.0
# ClientNamenodeProtocol#fsync          40.0   40.0    40.0        3.0
# ClientNamenodeProtocol#getFileInfo   215.0  213.0   215.0       24.0
# ClientNamenodeProtocol#getListing     43.0   43.0    43.0        3.0
# ClientNamenodeProtocol#rename         80.0   80.0    80.0        9.0
# DFSClient#rename                      80.0   80.0    80.0        9.0
# DFSOutputStream#close                 42.0   42.0    42.0        6.0
# DFSOutputStream#flushInternal         42.0   42.0    42.0        6.0
# DFSOutputStream#flushOrSync           40.0   40.0    40.0        3.0
# DFSOutputStream#write               7006.0  763.0  1486.0      688.0
# DataStreamer#writeTo                 602.0  507.0   602.0      113.0
# DistributedFileSystem#create          42.0   42.0    42.0        4.0
# completeFile                          42.0   42.0    42.0        6.0
# dataStreamer                         602.0  170.0   202.0       58.0
# getFileInfo                          215.0  213.0   215.0       24.0
# hflush                                40.0   40.0    40.0        3.0
# listPaths                             43.0   43.0    43.0        3.0
# newStreamForCreate                    42.0   42.0    42.0        4.0
# waitForAckedSeqno                     82.0   82.0    82.0        9.0
#
#                                     概率采样(0.01)
# BlockReaderRemote2#readNextPacket          8.0
# ClientNamenodeProtocol#addBlock            NaN
# ClientNamenodeProtocol#complete            1.0
# ClientNamenodeProtocol#create              1.0
# ClientNamenodeProtocol#fsync               1.0
# ClientNamenodeProtocol#getFileInfo         4.0
# ClientNamenodeProtocol#getListing          NaN
# ClientNamenodeProtocol#rename              1.0
# DFSClient#rename                           1.0
# DFSOutputStream#close                      1.0
# DFSOutputStream#flushInternal              1.0
# DFSOutputStream#flushOrSync                1.0
# DFSOutputStream#write                     78.0
# DataStreamer#writeTo                      17.0
# DistributedFileSystem#create               1.0
# completeFile                               1.0
# dataStreamer                              11.0
# getFileInfo                                4.0
# hflush                                     1.0
# listPaths                                  NaN
# newStreamForCreate                         1.0
# waitForAckedSeqno                          2.0
# data/wordcount/
#                                       全采样   限制采样  令牌桶采样  概率采样(0.1)  概率采样(0.01)
# BlockReaderRemote2#readNextPacket   126.0    5.0    2.0        8.0         1.0
# ClientNamenodeProtocol#addBlock      40.0   40.0   40.0        2.0         NaN
# ClientNamenodeProtocol#complete      41.0   41.0   41.0        2.0         NaN
# ClientNamenodeProtocol#create        41.0   41.0   41.0        5.0         1.0
# ClientNamenodeProtocol#getFileInfo  204.0  204.0  204.0       21.0         4.0
# ClientNamenodeProtocol#getListing    42.0   42.0   42.0        1.0         NaN
# ClientNamenodeProtocol#rename        80.0   80.0   80.0        5.0         2.0
# DFSClient#rename                     80.0   80.0   80.0        5.0         2.0
# DFSOutputStream#close                41.0   41.0   41.0        2.0         NaN
# DFSOutputStream#flushInternal        41.0   41.0   41.0        2.0         NaN
# DFSOutputStream#write                40.0   40.0   40.0        2.0         NaN
# DFSOutputStream#writeChunk           77.0   77.0   77.0        4.0         NaN
# DataStreamer#writeTo                 80.0   80.0   80.0       15.0         1.0
# DistributedFileSystem#create         41.0   41.0   41.0        5.0         1.0
# completeFile                         41.0   41.0   41.0        2.0         NaN
# dataStreamer                         80.0   80.0   80.0        4.0         NaN
# getFileInfo                         204.0  204.0  204.0       21.0         4.0
# listPaths                            42.0   42.0   42.0        1.0         NaN
# newStreamForCreate                   41.0   41.0   41.0        5.0         1.0
# waitForAckedSeqno                    41.0   41.0   41.0        2.0         NaN
