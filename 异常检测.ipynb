# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from htrace import Parse
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %config InlineBackend.figure_formats = ['svg']
sns.set_style("whitegrid")

# %%
data_path={
    'dfsioe_r': 'data/dfsioe_r/',
    'dfsioe_w': 'data/dfsioe_w/',
    'kmeans': 'data/kmeans/',
    'pagerank': 'data/pagerank/',
    'terasort': 'data/terasort/',
    'wordcount': 'data/wordcount/'
}

# %%
def clean_src_csv(path):
    df = pd.read_csv(path)
    df.index = df['Unnamed: 0']
    df.drop(['Unnamed: 0'],axis=1, inplace=True)
    df = df.T
    df =df.drop(['min','25%'], axis=1)
    df.columns = list(map(lambda x: path.split('/')[2]+'-'+x,['count','mean','std','50%','75%','max']))
    return df

# %% [markdown]
# ### wordcount

# %%
bench = 'data/terasort/'
ans = []
for i in range(1):
    c = clean_src_csv(bench+'l/'+str(i+1)+'.csv')
    c = c[c['l-count']>10]
    tar = pd.read_csv(bench+'l/'+str(i+1)+'s.csv')
    err = []
    x = []
    for i in c.iterrows():
        d = tar[tar['name']==i[0]]
        res = 0
        for j in d.iterrows():
            if j[1]['time'] > 1.5*i[1]['l-50%']:
                res += 1
        err.append((res/i[1]['l-count'])*100)
        x.append(res)
    c['err%'] = err
    c['res'] = x
    ans.append(c[
        (c['err%']<30)
        &(c['err%']>0)
        &(c['l-max']>1)
    ].sort_values('err%'))
c = pd.concat(ans, axis=1)
c.dropna(axis=0,how='any')
# Out:
#                                     l-count     l-mean      l-std  l-50%  \
# DFSInputStream#readWithStrategy      4638.0   0.026089   1.312819    0.0
# ClientNamenodeProtocol#getFileInfo    213.0   0.845070   3.782960    1.0
# getFileInfo                           213.0   1.197183   6.419942    1.0
# DFSInputStream#byteArrayRead         4638.0   0.066192   1.326614    0.0
# DFSOutputStream#flushInternal          42.0   4.214286   9.981778    3.0
# ClientNamenodeProtocol#fsync           40.0   5.250000   3.069703    5.0
# DataStreamer#writeTo                  507.0   0.601578   0.585596    1.0
# DFSOutputStream#close                  42.0   9.309524  12.487043    6.0
# completeFile                           42.0   4.785714   6.205960    3.0
# ClientNamenodeProtocol#create          42.0   5.238095   2.057817    5.0
# ClientNamenodeProtocol#complete        42.0   4.595238   6.192283    3.0
# DFSOutputStream#write                 763.0   0.173001   0.745207    0.0
# dataStreamer                          170.0   4.023529   6.876728    3.0
# DFSOutputStream#flushOrSync            40.0  13.275000   5.870340   11.0
# hflush                                 40.0  13.300000   5.879997   11.0
# newStreamForCreate                     42.0   6.380952   4.460955    5.0
# DistributedFileSystem#create           42.0   6.761905   6.051847    5.0
# ClientNamenodeProtocol#rename          80.0   4.937500   3.597973    4.0
# DFSClient#rename                       80.0   5.087500   3.611493    4.0
#
#                                     l-75%  l-max       err%  res
# DFSInputStream#readWithStrategy      0.00   89.0   0.539025   25
# ClientNamenodeProtocol#getFileInfo   1.00   55.0   2.347418    5
# getFileInfo                          1.00   94.0   3.755869    8
# DFSInputStream#byteArrayRead         0.00   89.0   4.549375  211
# DFSOutputStream#flushInternal        3.00   67.0   4.761905    2
# ClientNamenodeProtocol#fsync         5.00   23.0   5.000000    2
# DataStreamer#writeTo                 1.00    2.0   5.128205   26
# DFSOutputStream#close                6.00   78.0   9.523810    4
# completeFile                         4.00   39.0  11.904762    5
# ClientNamenodeProtocol#create        6.75   12.0  11.904762    5
# ClientNamenodeProtocol#complete      4.00   39.0  11.904762    5
# DFSOutputStream#write                0.00   13.0  14.023591  107
# dataStreamer                         4.00   65.0  20.588235   35
# DFSOutputStream#flushOrSync         16.25   37.0  25.000000   10
# hflush                              16.25   37.0  25.000000   10
# newStreamForCreate                   7.75   32.0  26.190476   11
# DistributedFileSystem#create         7.75   43.0  26.190476   11
# ClientNamenodeProtocol#rename        7.00   28.0  26.250000   21
# DFSClient#rename                     7.00   28.0  28.750000   23

# %% [markdown]
# ### kmeans

# %%
bench = 'data/kmeans/'
ans = []
for i in range(1):
    c = clean_src_csv(bench+'l/'+str(i+1)+'.csv')
    c = c[c['l-count']>10]
    tar = pd.read_csv(bench+'l/'+str(i+1)+'s.csv')
    err = []
    x = []
    for i in c.iterrows():
        d = tar[tar['name']==i[0]]
        res = 0
        for j in d.iterrows():
            if j[1]['time'] > 1.5*i[1]['l-50%']:
                res += 1
        err.append((res/i[1]['l-count'])*100)
        x.append(res)
    c['err%'] = err
    c['res'] = x
    ans.append(c[
        (c['err%']<30)
        &(c['err%']>0)
        &(c['l-max']>1)
    ].sort_values('err%'))
c = pd.concat(ans, axis=1)
c.dropna(axis=0,how='any')
# Out:
#                                           l-count     l-mean      l-std  \
# DFSInputStream#readWithStrategy           39238.0   0.008181   0.597554
# ClientNamenodeProtocol#getBlockLocations    131.0   0.656489   0.507952
# DFSInputStream#byteArrayRead              39238.0   0.026683   0.618897
# ClientNamenodeProtocol#getFileInfo          219.0   0.904110   4.114745
# ClientNamenodeProtocol#getListing            73.0   0.630137   0.565362
# ClientNamenodeProtocol#addBlock              22.0   9.500000   3.474396
# ClientNamenodeProtocol#rename                21.0   4.190476   2.581067
# getFileInfo                                 219.0   1.182648   5.984956
# completeFile                                 28.0   5.285714   2.733295
# getBlockLocations                           131.0   1.183206   2.231941
# DFSInputStream#openInfo                     131.0   1.206107   2.231652
# DFSClient#rename                             21.0   4.476190   2.676174
# newDFSInputStream                           131.0   1.320611   2.807318
# ClientNamenodeProtocol#complete              28.0   4.964286   2.531024
# listPaths                                    73.0   1.246575   2.337976
# DFSOutputStream#write                       567.0   0.165785   0.416990
# DistributedFileSystem#open                  131.0   1.419847   3.065827
# DFSOutputStream#close                        28.0  22.642857  15.949490
# ClientNamenodeProtocol#create                28.0   6.821429   4.320953
# newStreamForCreate                           28.0   8.178571   6.307277
# DistributedFileSystem#create                 28.0   8.571429   7.465618
#
#                                           l-50%  l-75%  l-max       err%  res
# DFSInputStream#readWithStrategy             0.0   0.00   87.0   0.321117  126
# ClientNamenodeProtocol#getBlockLocations    1.0   1.00    2.0   1.526718    2
# DFSInputStream#byteArrayRead                0.0   0.00   88.0   2.110199  828
# ClientNamenodeProtocol#getFileInfo          1.0   1.00   61.0   3.196347    7
# ClientNamenodeProtocol#getListing           1.0   1.00    2.0   4.109589    3
# ClientNamenodeProtocol#addBlock            10.5  11.00   16.0   4.545455    1
# ClientNamenodeProtocol#rename               4.0   5.00   14.0   4.761905    1
# getFileInfo                                 1.0   1.00   89.0   5.022831   11
# completeFile                                5.5   7.00   13.0   7.142857    2
# getBlockLocations                           1.0   1.00   26.0   7.633588   10
# DFSInputStream#openInfo                     1.0   1.00   26.0   9.160305   12
# DFSClient#rename                            4.0   5.00   14.0   9.523810    2
# newDFSInputStream                           1.0   1.00   32.0  10.687023   14
# ClientNamenodeProtocol#complete             5.0   6.25   13.0  10.714286    3
# listPaths                                   1.0   1.00   20.0  13.698630   10
# DFSOutputStream#write                       0.0   0.00    5.0  15.873016   90
# DistributedFileSystem#open                  1.0   1.00   35.0  16.030534   21
# DFSOutputStream#close                      22.5  29.25   83.0  17.857143    5
# ClientNamenodeProtocol#create               6.0   7.50   19.0  17.857143    5
# newStreamForCreate                          6.0   8.50   32.0  25.000000    7
# DistributedFileSystem#create                6.0   8.50   40.0  25.000000    7

# %% [markdown]
# ### pagerank

# %%
bench = 'data/pagerank/'
ans = []
for i in range(1):
    c = clean_src_csv(bench+'l/'+str(i+1)+'.csv')
    c = c[c['l-count']>10]
    tar = pd.read_csv(bench+'l/'+str(i+1)+'s.csv')
    err = []
    x = []
    for i in c.iterrows():
        d = tar[tar['name']==i[0]]
        res = 0
        for j in d.iterrows():
            if j[1]['time'] > 1.5*i[1]['l-50%']:
                res += 1
        err.append((res/i[1]['l-count'])*100)
        x.append(res)
    c['err%'] = err
    c['res'] = x
    ans.append(c[
        (c['err%']<30)
        &(c['err%']>10)
        &(c['l-max']>1)
    ].sort_values('err%'))
c = pd.concat(ans, axis=1)
c.dropna(axis=0,how='any')
# Out:
#                                           l-count     l-mean      l-std  \
# BlockReaderRemote2#readNextPacket           133.0   0.774436   1.048928
# DFSOutputStream#close                       247.0  22.991903  23.838548
# ClientNamenodeProtocol#getBlockLocations    301.0   1.827243   4.961524
# ClientNamenodeProtocol#create               247.0   8.846154  12.022025
# DistributedFileSystem#create                247.0   9.716599  12.736249
# newStreamForCreate                          247.0   9.587045  12.498435
# getBlockLocations                           301.0   2.119601   4.964438
# newDFSInputStream                           301.0   2.225914   5.054581
# DFSInputStream#openInfo                     301.0   2.159468   4.994779
# DFSOutputStream#write                      1726.0   0.161645   0.416960
# DistributedFileSystem#open                  301.0   2.299003   5.089561
# DFSClient#delete                             12.0   9.333333   9.138662
# delete                                       12.0   9.250000   9.176303
# ClientNamenodeProtocol#delete                12.0   8.750000   9.086704
# DistributedFileSystem#delete                 12.0   9.416667   9.119991
# DataStreamer#writeTo                       1224.0   0.193627   0.502740
# ClientNamenodeProtocol#addBlock             129.0  10.744186   8.094442
# dataStreamer                                547.0   7.928702  14.042206
#
#                                           l-50%  l-75%  l-max       err%  res
# BlockReaderRemote2#readNextPacket           1.0   1.00   10.0  11.278195   15
# DFSOutputStream#close                      21.0  27.00  281.0  11.336032   28
# ClientNamenodeProtocol#getBlockLocations    1.0   1.00   47.0  13.953488   42
# ClientNamenodeProtocol#create               6.0   7.00  106.0  14.170040   35
# DistributedFileSystem#create                7.0   8.00  108.0  14.170040   35
# newStreamForCreate                          7.0   8.00  107.0  14.170040   35
# getBlockLocations                           1.0   1.00   47.0  14.285714   43
# newDFSInputStream                           1.0   1.00   47.0  14.617940   44
# DFSInputStream#openInfo                     1.0   1.00   47.0  14.617940   44
# DFSOutputStream#write                       0.0   0.00    5.0  14.889919  257
# DistributedFileSystem#open                  1.0   1.00   47.0  15.614618   47
# DFSClient#delete                            6.0   7.00   38.0  16.666667    2
# delete                                      6.0   7.00   38.0  16.666667    2
# ClientNamenodeProtocol#delete               6.0   7.00   37.0  16.666667    2
# DistributedFileSystem#delete                6.0   7.25   38.0  16.666667    2
# DataStreamer#writeTo                        0.0   0.00    8.0  16.748366  205
# ClientNamenodeProtocol#addBlock             8.0  12.00   60.0  24.031008   31
# dataStreamer                                4.0   7.00  269.0  25.045704  137
