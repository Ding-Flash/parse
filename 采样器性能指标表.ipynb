# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from htrace import Parse
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# pd.set_option('display.float_format', lambda x: '%.3f' % x)
# %config InlineBackend.figure_formats = ['svg']
sns.set_style("whitegrid")
from util import merge_info_display, merge_info

# %%
data_path={
    'dfsioe_r': 'ndata/dfsioe_r/',
    'dfsioe_w': 'ndata/dfsioe_w/',
    'kmeans': 'ndata/kmeans/',
    'pagerank': 'ndata/pagerank/',
    'terasort': 'ndata/terasort/',
    'wordcount': 'ndata/wordcount/'
}
samplers = ['a', 'l', 't', 'p0.1', 'p0.01']

# %% [markdown]
# ## 不同bench的采样器采样指标(表)

# %%
for k,p in data_path.items():
    print(k)
    merge_info(p, samplers)
# Out:
# dfsioe_r
#         node  tree      dist        en       size     time     ctime  \
# always    40  20.0  0.000000  1.388010  33.291745  21.1650  0.109393
# bump      40  20.0  2.423469  2.871789   1.310271  19.8798  0.042027
# tbuck     40  20.0  2.827234  2.666051   1.486667  20.1236  0.054807
# p0.1      31  13.4  4.487782  1.396188   3.308570  19.9918  0.047898
# p0.01     15   6.6  9.619053  1.386140   0.335021  18.6016 -0.024971
#
#            through  cthrough
# always  15942085.0 -0.084432
# bump    17899040.6  0.027958
# tbuck   16777091.0 -0.036477
# p0.1    17772706.2  0.020702
# p0.01   18150479.0  0.042398
# dfsioe_w
#         node  tree      dist        en        size     time     ctime  \
# always  40.0  20.0  0.000000  0.638730  134.073542  34.3370  0.684921
# bump    40.0  21.0  6.041781  1.422715    7.512202  20.9808  0.029530
# tbuck   40.0  21.0  6.949038  1.511855    7.479428  21.7754  0.068522
# ...

# %% [markdown]
# !! wordcount的 0.1 和 0.01 位置换一下
