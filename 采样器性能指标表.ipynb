# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from htrace import Parse
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# pd.set_option('display.float_format', lambda x: '%.3f' % x)
# %config InlineBackend.figure_formats = ['svg']
sns.set_style("whitegrid")
from util import merge_info_display

# %%
data_path={
    'dfsioe_r': 'data/dfsioe_r/',
    'dfsioe_w': 'data/dfsioe_w/',
    'kmeans': 'data/kmeans/',
    'pagerank': 'data/pagerank/',
    'terasort': 'data/terasort/',
    'wordcount': 'data/wordcount/'
}
samplers = ['a', 'l', 't', 'p0.01', 'p0.1']

# %% [markdown]
# ## 不同bench的采样器采样指标(表)

# %%
for k,p in data_path.items():
    merge_info_display(p, samplers)
# Out:
# +----------------+--------+------------+
# |     bench      |  时间  |   吞吐量   |
# +----------------+--------+------------+
# | data/dfsioe_r/ | 19.378 | 17412232.0 |
# +----------------+--------+------------+
#             函数种类  调用树种类   相似度(欧氏)       信息熵    文件大小(M)     执行时间         吞吐量
# 全采样         40.0   20.0  0.000000  1.388010  33.291745  21.1650  15942085.0
# 概率采样(0.1)   31.0   13.4  4.487782  1.396188   3.308570  18.9918  17772706.2
# 限速采样        40.0   21.0  2.423469  2.871789   1.310271  18.8798  17899040.6
# 令牌桶采样       40.0   20.0  2.827234  2.666051   1.486667  20.1236  16777091.0
# 概率采样(0.01)  15.0    6.6  9.619053  1.386140   0.335021  18.6016  18150479.0
# +----------------+--------+------------+
# |     bench      |  时间  |   吞吐量   |
# +----------------+--------+------------+
# | data/dfsioe_w/ | 21.193 | 16009898.0 |
# +----------------+--------+------------+
#             函数种类  调用树种类   相似度(欧氏)       信息熵     文件大小(M)     执行时间         吞吐量
# 全采样         40.0   20.0  0.000000  0.638725  134.071968  33.5700  10106618.0
# 概率采样(0.1)   30.0   14.8  5.517660  0.680493   13.519001  21.0086  16154762.2
# 限速采样        38.4   19.0  4.108717  1.948052    3.296031  21.7954  15579376.2
# 令牌桶采样       39.2   20.2  4.471686  1.838233    3.131275  21.8312  15554077.2
# 概率采样(0.01)  16.2    7.2  7.070531  0.681299    1.324290  22.0928  15382567.2
# +--------------+--------+---------+
# |    bench     |  时间  |  吞吐量 |
# +--------------+--------+---------+
# | data/kmeans/ | 26.016 | 53667.0 |
# +--------------+--------+---------+
#             函数种类  调用树种类    相似度(欧氏)       信息熵     文件大小(M)     执行时间      吞吐量
# 全采样         38.0   19.0   0.000000  1.026861  617.817284  59.5270  23455.0
# 概率采样(0.1)   30.0   14.0   6.140625  1.027247   61.725016  31.7848  43941.8
# 限速采样        38.0   19.0   4.046647  1.532853   15.827707  26.4252  52871.0
# 令牌桶采样       38.0   18.2   6.124315  2.686888    2.317002  26.9428  51830.6
# 概率采样(0.01)  17.4    7.8  10.297438  1.027204    6.173533  26.6448  52411.2
# +----------------+--------+----------+
# |     bench      |  时间  |  吞吐量  |
# +----------------+--------+----------+
# | data/pagerank/ | 151.24 | 145783.0 |
# +----------------+--------+----------+
#             函数种类  调用树种类    相似度(欧氏)       信息熵    文件大小(M)      执行时间       吞吐量
# 全采样         38.0   19.0   0.000000  1.699517  94.887314  161.5310  136495.0
# 概率采样(0.1)   33.4   17.2  10.155465  1.731483   9.556328  154.9936  142389.6
# 限速采样        37.0   19.0   9.052705  3.043336   5.366075  152.3218  144755.4
# 令牌桶采样       38.0   20.0   8.825106  2.798428   7.669520  152.3114  144768.2
# 概率采样(0.01)  27.0   13.0  10.729445  1.721568   0.948791  145.1156  152003.8
# +----------------+--------+-----------+
# |     bench      |  时间  |   吞吐量  |
# +----------------+--------+-----------+
# | data/terasort/ | 11.273 | 2838641.0 |
# +----------------+--------+-----------+
#             函数种类  调用树种类   相似度(欧氏)       信息熵     文件大小(M)     执行时间        吞吐量
# 全采样         41.0     20  0.000000  1.388872  170.306904  20.3460  1572790.0
# 概率采样(0.1)   27.4     13  7.891215  1.389673   17.012536  12.0258  2665613.4
# 限速采样        41.0     20  4.644183  2.433988    3.512214  11.5638  2768642.0
# 令牌桶采样       41.0     20  4.586939  1.941046    3.450735  11.8676  2704491.6
# 概率采样(0.01)  17.0      9  9.520378  1.386282    1.685136  11.9178  2687195.4
# +-----------------+--------+----------+
# |      bench      |  时间  |  吞吐量  |
# +-----------------+--------+----------+
# | data/wordcount/ | 9.2376 | 891362.4 |
# +-----------------+--------+----------+
#             函数种类  调用树种类   相似度(欧氏)       信息熵    文件大小(M)     执行时间       吞吐量
# 全采样         38.0   14.0  0.000000  1.068274  47.237131  11.6170  706877.0
# 概率采样(0.1)   11.8    5.4  7.870595  1.073550   0.473740   9.6352  854023.6
# 限速采样        38.0   14.0  2.727899  1.960656   1.882379   9.7078  845909.0
# 令牌桶采样       38.0   14.0  2.724665  2.993367   0.707778   9.7644  841147.2
# 概率采样(0.01)  27.4    9.4  3.383353  1.067455   4.729335   9.3462  878963.0

# %% [markdown]
# !! wordcount的 0.1 和 0.01 位置换一下
